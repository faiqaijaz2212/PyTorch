# %%
def dy_dx(x):
    return 2 * x

# %%
dy_dx(5)
# Out:
# 10

# %%
import math

def dz_dx(x):
    return 2 * x * math.cos(x)

# %%
dz_dx(5)
# Out:
# 2.8366218546322624

# %%
import torch

# %% [markdown]
# # y = x^2

# %%
x=torch.tensor(3.0, requires_grad=True)

# %%
y=x**2

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %% [markdown]
# # y = x^2 , z = sin(y)

# %%
x=torch.tensor(3.0, requires_grad=True)
print(x)
# Out:
# tensor(3., requires_grad=True)

# %%
y = x ** 2
print(y)
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
z = torch.sin(y)

# %%
z
# Out:
# tensor(0.4121, grad_fn=<SinBackward0>)

# %%
z.backward()

# %%
x.grad
# Out:
# tensor(-5.4668)

# %%
import torch
x=torch.tensor(6.7)
y=torch.tensor(0.0)
w=torch.tensor(1.0)
b=torch.tensor(0.0)

# %%
# Binary cross entropy loss for scalar

def binary_cross_entropy_loss(prediction, target):
    epsilon = 1e-8
    prediction = torch.clamp(prediction, epsilon, 1 - epsilon)
    return - (target * torch.log(prediction) + (1 - target) * torch.log(1 - prediction))

# %%
# Forward pass

z= w * x + b
y_pred=torch.sigmoid(z)
loss=binary_cross_entropy_loss(y_pred, y)

# %%
loss
# Out:
# tensor(6.7012)

# %%
# Derivatives

dloss_dy_pred = (y_pred-y)/(y_pred*(1-y_pred))
dy_pred_dz=y_pred*(1-y_pred)
dz_dw = x
dz_db = 1
dl_dw = dloss_dy_pred * dy_pred_dz * dz_dw
dl_db = dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"Manual gradient loss w.r.t weight: {dl_dw}")
print(f"Manual gradient loss w.r.t bias: {dl_db}")
# Out:
# Manual gradient loss w.r.t weight: 6.691762447357178
# Manual gradient loss w.r.t bias: 0.998770534992218

# %% [markdown]
# # Using AutoGrad

# %%
x=torch.tensor(6.7)
y=torch.tensor(0.0)
w=torch.tensor(1.0,requires_grad=True)
b=torch.tensor(0.0,requires_grad=True)

# %%
z=w*x+b
z
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)

# %%
y_pred=torch.sigmoid(z)
y_pred
# Out:
# tensor(0.9988, grad_fn=<SigmoidBackward0>)

# %%
loss=binary_cross_entropy_loss(y_pred, y)

# %%
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
w.grad
# Out:
# tensor(6.6918)

# %%
b.grad
# Out:
# tensor(0.9988)

# %% [markdown]
# # Vector

# %%
x=torch.tensor([1.0,2.0,3.0], requires_grad=True)

# %%
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y = (x**2).mean()

# %%
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %%
# clearing grads
import torch
x = torch.tensor(2.0, requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x ** 2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(8.)

# %%
y = x ** 2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(12.)

# %%
x.grad.zero_()
# Out:
# tensor(0.)

# %%
y = x ** 2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
# requires grad function
x.requires_grad_(False)
# Out:
# tensor(2.)

# %%
x
# Out:
# tensor(2.)

# %%
y = x**2

# %%
y
# Out:
# tensor(4.)

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 y.backward()
#
# File ~/Desktop/Pytorch/.venv/lib/python3.8/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~/Desktop/Pytorch/.venv/lib/python3.8/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~/Desktop/Pytorch/.venv/lib/python3.8/site-packages/torch/autograd/graph.py:769, in _engine_run_backward(t_outputs, *args, **kwargs)
#     767     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768 try:
# --> 769     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770         t_outputs, *args, **kwargs
#     771     )  # Calls into the C++ engine to run the backward pass
#     772 finally:
#     773     if attach_logging_hooks:
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn

# %%
# detach method
z=x.detach_()

# %%
z
# Out:
# tensor(2.)

# %%
x=torch.tensor(2.0, requires_grad=True)
print(x)
# Out:
# tensor(2., requires_grad=True)

# %%
y=x**2

# %%
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y1=z**2

# %%
y1
# Out:
# tensor(4.)

# %%
y.backward()

# %%
y1.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 y1.backward()
#
# File ~/Desktop/Pytorch/.venv/lib/python3.8/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~/Desktop/Pytorch/.venv/lib/python3.8/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~/Desktop/Pytorch/.venv/lib/python3.8/site-packages/torch/autograd/graph.py:769, in _engine_run_backward(t_outputs, *args, **kwargs)
#     767     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768 try:
# --> 769     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770         t_outputs, *args, **kwargs
#     771     )  # Calls into the C++ engine to run the backward pass
#     772 finally:
#     773     if attach_logging_hooks:
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn

# %%
# with statement
with torch.no_grad():
    y = x ** 2

# %%
y
# Out:
# tensor(4.)

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 y.backward()
#
# File ~/Desktop/Pytorch/.venv/lib/python3.8/site-packages/torch/_tensor.py:521, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     511 if has_torch_function_unary(self):
#     512     return handle_torch_function(
#     513         Tensor.backward,
#     514         (self,),
#    (...)
#     519         inputs=inputs,
#     520     )
# --> 521 torch.autograd.backward(
#     522     self, gradient, retain_graph, create_graph, inputs=inputs
#     523 )
#
# File ~/Desktop/Pytorch/.venv/lib/python3.8/site-packages/torch/autograd/__init__.py:289, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     284     retain_graph = create_graph
#     286 # The reason we repeat the same comment below is that
#     287 # some Python versions print out the first line of a multi-line function
#     288 # calls in the traceback and some print out the last line
# --> 289 _engine_run_backward(
#     290     tensors,
#     291     grad_tensors_,
#     292     retain_graph,
#     293     create_graph,
#     294     inputs,
#     295     allow_unreachable=True,
#     296     accumulate_grad=True,
#     297 )
#
# File ~/Desktop/Pytorch/.venv/lib/python3.8/site-packages/torch/autograd/graph.py:769, in _engine_run_backward(t_outputs, *args, **kwargs)
#     767     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     768 try:
# --> 769     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     770         t_outputs, *args, **kwargs
#     771     )  # Calls into the C++ engine to run the backward pass
#     772 finally:
#     773     if attach_logging_hooks:
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn
